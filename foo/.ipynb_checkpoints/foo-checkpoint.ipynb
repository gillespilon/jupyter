# %%
import pandas as pd

# %%
df = pd.read_csv('foo.csv')
df
# Out:
#     before  after  difference  wotevr
# 0        1    211         210     224
# 1        2    572           2     585
# 2        3    558           3     571
# 3        4    250           4     263
# 4        5    478           5     491
# 5        6    307           6     320
# 6        7    184           7     197
# 7        8    435           8     448
# 8        9    460           9     473
# 9       10    308          10     321
# 10      11    188          11     201
# 11      12    111          12     124
# 12      13    676          13     689
# 13      14    326          14     339
# 14      15    142          15     155
# 15      16    255          16     268
# 16      17    205          17     218
# 17      18     77          18      90
# 18      19    190          19     203
# 19      20    320          20     333
# 20      21    407          21     420
# 21      22    333          22     346
# 22      23    488          23     501
# 23      24    374          24     387
# ...

# %%
df[['before', 'after']]
# Out:
#     before  after
# 0        1    211
# 1        2    572
# 2        3    558
# 3        4    250
# 4        5    478
# 5        6    307
# 6        7    184
# 7        8    435
# 8        9    460
# 9       10    308
# 10      11    188
# 11      12    111
# 12      13    676
# 13      14    326
# 14      15    142
# 15      16    255
# 16      17    205
# 17      18     77
# 18      19    190
# 19      20    320
# 20      21    407
# 21      22    333
# 22      23    488
# 23      24    374
# 24      25    409

# %%
df
# Out:
#     before  after  difference  wotevr
# 0        1    211         210     224
# 1        2    572           2     585
# 2        3    558           3     571
# 3        4    250           4     263
# 4        5    478           5     491
# 5        6    307           6     320
# 6        7    184           7     197
# 7        8    435           8     448
# 8        9    460           9     473
# 9       10    308          10     321
# 10      11    188          11     201
# 11      12    111          12     124
# 12      13    676          13     689
# 13      14    326          14     339
# 14      15    142          15     155
# 15      16    255          16     268
# 16      17    205          17     218
# 17      18     77          18      90
# 18      19    190          19     203
# 19      20    320          20     333
# 20      21    407          21     420
# 21      22    333          22     346
# 22      23    488          23     501
# 23      24    374          24     387
# ...

# %%
after = df[['before', 'after']]
after
# Out:
#     before  after
# 0        1    211
# 1        2    572
# 2        3    558
# 3        4    250
# 4        5    478
# 5        6    307
# 6        7    184
# 7        8    435
# 8        9    460
# 9       10    308
# 10      11    188
# 11      12    111
# 12      13    676
# 13      14    326
# 14      15    142
# 15      16    255
# 16      17    205
# 17      18     77
# 18      19    190
# 19      20    320
# 20      21    407
# 21      22    333
# 22      23    488
# 23      24    374
# 24      25    409

# %%
another = df[['after', 'difference', 'wotever']]
another
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-e54a1866fcdc> in <module>()
# ----> 1 another = df[['after', 'difference', 'wotever']]
#       2 another
#
# /usr/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1961         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1962             # either boolean or fancy integer index
# -> 1963             return self._getitem_array(key)
#    1964         elif isinstance(key, DataFrame):
#    1965             return self._getitem_frame(key)
#
# /usr/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2005             return self.take(indexer, axis=0, convert=False)
#    2006         else:
# -> 2007             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2008             return self.take(indexer, axis=1, convert=True)
#    2009
#
# ...

# %%
after
# Out:
#     before  after
# 0        1    211
# 1        2    572
# 2        3    558
# 3        4    250
# 4        5    478
# 5        6    307
# 6        7    184
# 7        8    435
# 8        9    460
# 9       10    308
# 10      11    188
# 11      12    111
# 12      13    676
# 13      14    326
# 14      15    142
# 15      16    255
# 16      17    205
# 17      18     77
# 18      19    190
# 19      20    320
# 20      21    407
# 21      22    333
# 22      23    488
# 23      24    374
# 24      25    409
